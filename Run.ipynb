# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm

from Action import action
from Observation import observation
from Function_prop_score import MonteCarlo_prop_score


def Run(K, snr, X):
    SNR = snr
    T = 10000
    gamma = 0.01
    # initialization
    A = [action(T) for i in range(0, K)]
    Best_reward = -10
    Best_arm = 0
    Best_arm_estimator = 0
    for a in range(0, K):
        A[a].reward = np.random.normal(0, SNR)
        # record best arm and best reward
        if Best_reward < A[a].reward:
            Best_reward = A[a].reward
            Best_arm = a

    Best_reward_estimator = np.zeros(T + 1)
    available_action = [i for i in range(0, K)]

    # initialization of three estimators in the algorithm
    k = K
    tao = np.zeros((T + 2, k))
    miu_reward_estimator = np.zeros((T + 2, k))
    sigma_estimator = np.zeros((T + 2, k))

    # First Observation
    for x in range(0, X):
        for a in range(0, k):
            A[a].reward_mean = observation(A[a]).value
            A[a].pro_score[1] = 1 / k

    # loop begin
    for t in range(1, T + 1):

        # calculate cumulative regret at time t
        for a in available_action:   Best_reward_estimator[t] += A[a].pro_score[t] * A[a].reward

        # pull arm
        a_t = np.random.multinomial(1, [A[j].pro_score[t] for j in available_action])
        a_t = available_action[np.argwhere(a_t == 1)[0, 0]]

        # observe and update sample averages and counts
        ob = observation(A[a_t])
        re_past = A[a_t].reward_mean
        A[a_t].update_rm_n(ob)

        # update sampling distribution
        for a in available_action:
            tao[t, a] = re_past + (ob.value - re_past) / A[a].pro_score[t] if a == a_t else A[
                a].reward_mean

            s1 = sum(np.sqrt(A[a].pro_score[1:t + 1]) * tao[1:t + 1, a])
            s2 = sum(np.sqrt(A[a].pro_score[1:t + 1]))
            miu_reward_estimator[t, a] = s1 / s2

            s3 = sum([A[a].pro_score[s] * ((tao[s, a] - miu_reward_estimator[t, a]) ** 2 + 1) for s in range(1, t + 1)])
            sigma_estimator[t, a] = s3 / (s2 * s2)

        # arm elimination
        rem = []
        for a in available_action:
            p = 1
            for a1 in available_action:
                if a != a1:
                    p1 = norm.cdf((miu_reward_estimator[t, a] - miu_reward_estimator[t, a1]) / (
                            (sigma_estimator[t, a] ** 2 + sigma_estimator[t, a1] ** 2) ** 0.5))
                    p = min(p, p1)

            if p < 1 / T:
                rem.append(a)
                k -= 1

        for a in rem:
            available_action.remove(a)

        # compute propensity scores
        Prop_score = MonteCarlo_prop_score(miu_reward_estimator[t], sigma_estimator[t], available_action)
        for a in available_action:
            A[a].pro_score[t + 1] = Prop_score[a]
            A[a].pro_score[t + 1] = (1 - gamma) * A[a].pro_score[t + 1] + gamma / k

        # break after finding the best arm
        if len(available_action) == 1:
            Best_arm_estimator = available_action[0]
            print('END!')
            print('Best arm is the ' + str(Best_arm_estimator) + 'th arm.')
            break

        if len(available_action) == 0:
            print('end!')
            Best_arm_estimator = rem[0]
            for a in rem:
                Best_arm_estimator = a if A[a].reward_mean > A[Best_arm_estimator].reward_mean else Best_arm_estimator
            print('Best arm is the ' + str(Best_arm_estimator) + 'th arm.')
            break

    # print and calculate the best arm, cumulative regret arm*'s regret stopping time
    print('K=' + str(K) + '  t=' + str(t))
    cumulative_regret = sum(Best_reward - Best_reward_estimator[1:t + 1]) / t
    Regret = Best_reward - A[Best_arm_estimator].reward
    print('cumulative regret=' + str(cumulative_regret) + '    Arm* regret=' + str(Regret))
    print("{:-^25s}".format(""))
    return [cumulative_regret, Regret, t]

# %%
# Cu_Regret[k,i] stands for the cumulative regret at the ith loop. Regret and stop_time are defined similarly.
Cu_Regret = np.zeros((10, 64))
Regret = np.zeros((10, 64))
stop_time = np.zeros((10, 64))
for k in range(0, 10):
    for i in range(0, 64):
        Cu_Re, Re, st = Run(5 * k + 5, 0.125, 1)
        Cu_Regret[k, i] += Cu_Re
        stop_time[k, i] += st
        Regret[k, i] = Re
    print('For k=' + str(5*k+5) + ', the regret Average is ' + str(np.mean(Cu_Regret[k])))
    print("{:=^50s}".format(""))
# Out:
# END!
# Best arm is the 2th arm.
# K=5  t=21
# cumulative regret=0.22202381750658637    Arm* regret=0.2672665388251444
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=22
# cumulative regret=0.19753681332997772    Arm* regret=0.2098843280176539
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=68
# cumulative regret=0.17685519701788943    Arm* regret=0.1470673852704423
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=541
# cumulative regret=0.021111325166668946    Arm* regret=0.03212275498659149
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=71
# cumulative regret=0.18492964882016777    Arm* regret=0.19009372668686164
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=465
# cumulative regret=0.17737147368217415    Arm* regret=0.09727120766608978
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=29
# cumulative regret=0.22017945467192176    Arm* regret=0.2140312235824573
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=66
# cumulative regret=0.34151759002683263    Arm* regret=0.3574034166423993
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=60
# cumulative regret=0.17686334310975357    Arm* regret=0.18232768476177985
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=219
# cumulative regret=0.036819190239796656    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=148
# cumulative regret=0.025157129174811523    Arm* regret=0.1386982850932566
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=173
# cumulative regret=0.04899440214822247    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=222
# cumulative regret=0.016818931035879264    Arm* regret=0.031343509406273506
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=398
# cumulative regret=0.05059514235915218    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=32
# cumulative regret=0.03734218964302723    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=1
# cumulative regret=0.1184002931428291    Arm* regret=0.15754705613579895
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=18
# cumulative regret=0.022179694588256204    Arm* regret=0.019270862215915466
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=1
# cumulative regret=0.19129358682606162    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=304
# cumulative regret=0.006363616985241902    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=163
# cumulative regret=0.17208819260883518    Arm* regret=0.06685003880354079
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=277
# cumulative regret=0.042331474645995945    Arm* regret=0.022009083761575714
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=1
# cumulative regret=0.08776809875383296    Arm* regret=0.07856612048506201
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=24
# cumulative regret=0.05604603831417623    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=100
# cumulative regret=0.021189819483255316    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=326
# cumulative regret=0.11487708227708768    Arm* regret=0.10129172288922597
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=207
# cumulative regret=0.0222436869289508    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=127
# cumulative regret=0.18744496022555637    Arm* regret=0.19585704715683305
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=1711
# cumulative regret=0.020963657598441817    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=52
# cumulative regret=0.05112636801633122    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=1
# cumulative regret=0.10969181498642504    Arm* regret=0.3273767976267272
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=4
# cumulative regret=0.10237128773804907    Arm* regret=0.10409714837197423
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=38
# cumulative regret=0.18581523539358216    Arm* regret=0.18422633964111823
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=65
# cumulative regret=0.13176329889723987    Arm* regret=0.15224114429214075
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=155
# cumulative regret=0.09666130582209699    Arm* regret=0.18810373142789855
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=212
# cumulative regret=0.06035116167146097    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=14
# cumulative regret=0.0190568386272779    Arm* regret=0.0201987228435032
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=18
# cumulative regret=0.03973655614342343    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=330
# cumulative regret=0.19590160363930234    Arm* regret=0.19332568523210922
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=23
# cumulative regret=0.08307225150176599    Arm* regret=0.08498949255445473
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=247
# cumulative regret=0.22556154052978963    Arm* regret=0.1829304402531781
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=223
# cumulative regret=0.1991117558469752    Arm* regret=0.17568586129889135
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=637
# cumulative regret=0.10509366581348346    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=139
# cumulative regret=0.1981195980795061    Arm* regret=0.12086573310661215
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=34
# cumulative regret=0.04837502976871842    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=240
# cumulative regret=0.10884098686836283    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=107
# cumulative regret=0.01851100429593492    Arm* regret=0.015825772472388373
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=1
# cumulative regret=0.17000602295211786    Arm* regret=0.08928368991353958
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=164
# cumulative regret=0.13364596866929185    Arm* regret=0.06652132266979743
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=86
# cumulative regret=0.15058572489241423    Arm* regret=0.17705657582170728
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=558
# cumulative regret=0.11773151283271348    Arm* regret=0.0987290179116993
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=150
# cumulative regret=0.06694727885167652    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=74
# cumulative regret=0.05561298658283967    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=25
# cumulative regret=0.2321746151649517    Arm* regret=0.23627376807345846
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=87
# cumulative regret=0.02099793494261394    Arm* regret=0.020534005530820743
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=40
# cumulative regret=0.11225992345168294    Arm* regret=0.08736220998952249
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=107
# cumulative regret=0.2503216558491223    Arm* regret=0.24533001897327378
# -------------------------
# END!
# Best arm is the 4th arm.
# K=5  t=184
# cumulative regret=0.06357058588079582    Arm* regret=0.11782397556123939
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=50
# cumulative regret=0.14424329415589343    Arm* regret=0.12420172954880285
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=19
# cumulative regret=0.07677431405068101    Arm* regret=0.05656470877050389
# -------------------------
# END!
# Best arm is the 0th arm.
# K=5  t=155
# cumulative regret=0.2966730950771391    Arm* regret=0.30071063261851
# -------------------------
# END!
# Best arm is the 2th arm.
# K=5  t=49
# cumulative regret=0.05903516690442028    Arm* regret=0.08956695266728866
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=413
# cumulative regret=0.19868432092913918    Arm* regret=0.22905671143491035
# -------------------------
# END!
# Best arm is the 3th arm.
# K=5  t=55
# cumulative regret=0.13701817077710024    Arm* regret=0.13508647776516033
# -------------------------
# END!
# Best arm is the 1th arm.
# K=5  t=84
# cumulative regret=0.14781338624654441    Arm* regret=0.1504394390762455
# -------------------------
# For k=5, the regret Average is 0.11579004862753509
# ==================================================
# END!
# Best arm is the 7th arm.
# K=10  t=247
# cumulative regret=0.11607665620159446    Arm* regret=0.22379281778892224
# -------------------------
# END!
# Best arm is the 5th arm.
# K=10  t=312
# cumulative regret=0.14401977599957985    Arm* regret=0.12485079256329006
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=1
# cumulative regret=0.2088923364707128    Arm* regret=0.11452025382086911
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=1
# cumulative regret=0.27611035938801987    Arm* regret=0.15613568533557942
# -------------------------
# END!
# Best arm is the 7th arm.
# K=10  t=1
# cumulative regret=0.14911359297563767    Arm* regret=0.25169852439634466
# -------------------------
# END!
# Best arm is the 4th arm.
# K=10  t=784
# cumulative regret=0.11689313330989985    Arm* regret=0.12776232072431476
# -------------------------
# END!
# Best arm is the 1th arm.
# K=10  t=629
# cumulative regret=0.029837401070066518    Arm* regret=0.007134428245563679
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=270
# cumulative regret=0.037575510113891715    Arm* regret=0.021408234369575008
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=1
# cumulative regret=0.2713575231235698    Arm* regret=0.37673260741996806
# -------------------------
# END!
# Best arm is the 1th arm.
# K=10  t=117
# cumulative regret=0.08337775783839782    Arm* regret=0.04541190594686351
# -------------------------
# END!
# Best arm is the 7th arm.
# K=10  t=1
# cumulative regret=0.2817462182859819    Arm* regret=0.6211223052807416
# -------------------------
# END!
# Best arm is the 9th arm.
# K=10  t=471
# cumulative regret=0.0887872938043498    Arm* regret=0.055614637417487095
# -------------------------
# END!
# Best arm is the 1th arm.
# K=10  t=59
# cumulative regret=0.09800408308939457    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=854
# cumulative regret=0.06989561718693775    Arm* regret=0.05188310250562194
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=233
# cumulative regret=0.10782677255868116    Arm* regret=0.05916811087728688
# -------------------------
# END!
# Best arm is the 1th arm.
# K=10  t=1
# cumulative regret=0.1785694023213549    Arm* regret=0.04317097737487119
# -------------------------
# END!
# Best arm is the 2th arm.
# K=10  t=1
# cumulative regret=0.18650687182874728    Arm* regret=0.2991922580576616
# -------------------------
# END!
# Best arm is the 4th arm.
# K=10  t=1
# cumulative regret=0.24170706291986327    Arm* regret=0.2761117704543957
# -------------------------
# END!
# Best arm is the 5th arm.
# K=10  t=490
# cumulative regret=0.23105365448790904    Arm* regret=0.21782371106344187
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=1
# cumulative regret=0.18620135971613605    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 1th arm.
# K=10  t=76
# cumulative regret=0.03680982412284193    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=203
# cumulative regret=0.25765417237880656    Arm* regret=0.2600138575001128
# -------------------------
# END!
# Best arm is the 8th arm.
# K=10  t=1
# cumulative regret=0.3041158697932149    Arm* regret=0.22295951017887458
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=661
# cumulative regret=0.15754716759155948    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=1
# cumulative regret=0.22113481833405887    Arm* regret=0.21490872686073054
# -------------------------
# END!
# Best arm is the 9th arm.
# K=10  t=539
# cumulative regret=0.03965700432144355    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=542
# cumulative regret=0.08757549970942566    Arm* regret=0.08470735734843757
# -------------------------
# END!
# Best arm is the 4th arm.
# K=10  t=147
# cumulative regret=0.16980253944508383    Arm* regret=0.14427429291019214
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=349
# cumulative regret=0.17904343009301796    Arm* regret=0.16352796009320783
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=1
# cumulative regret=0.1534247178369142    Arm* regret=0.18752441549121796
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=712
# cumulative regret=0.16957631313852176    Arm* regret=0.1350020242891085
# -------------------------
# END!
# Best arm is the 7th arm.
# K=10  t=102
# cumulative regret=0.164075989840303    Arm* regret=0.16376318803469989
# -------------------------
# END!
# Best arm is the 2th arm.
# K=10  t=135
# cumulative regret=0.04122225808238266    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 8th arm.
# K=10  t=160
# cumulative regret=0.2123477689750355    Arm* regret=0.21835548205454877
# -------------------------
# END!
# Best arm is the 7th arm.
# K=10  t=197
# cumulative regret=0.15047752232756384    Arm* regret=0.17838003274397007
# -------------------------
# END!
# Best arm is the 8th arm.
# K=10  t=1
# cumulative regret=0.29206998606964457    Arm* regret=0.42551826361191114
# -------------------------
# END!
# Best arm is the 7th arm.
# K=10  t=69
# cumulative regret=0.23148227125286513    Arm* regret=0.16529357043132398
# -------------------------
# END!
# Best arm is the 9th arm.
# K=10  t=339
# cumulative regret=0.058854766105997026    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 7th arm.
# K=10  t=535
# cumulative regret=0.12174852198390462    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=1
# cumulative regret=0.1110975664160217    Arm* regret=0.13500742674286081
# -------------------------
# END!
# Best arm is the 2th arm.
# K=10  t=27
# cumulative regret=0.09933733199248881    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=235
# cumulative regret=0.044977053309202694    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 2th arm.
# K=10  t=366
# cumulative regret=0.012815496382783394    Arm* regret=0.009397662410263588
# -------------------------
# END!
# Best arm is the 3th arm.
# K=10  t=176
# cumulative regret=0.060565530960038964    Arm* regret=0.061388792994842706
# -------------------------
# END!
# Best arm is the 8th arm.
# K=10  t=318
# cumulative regret=0.15484229890110876    Arm* regret=0.09899980486595045
# -------------------------
# END!
# Best arm is the 2th arm.
# K=10  t=50
# cumulative regret=0.08703861480775472    Arm* regret=0.020599787248775925
# -------------------------
# END!
# Best arm is the 5th arm.
# K=10  t=1
# cumulative regret=0.2875115751789795    Arm* regret=0.3004801681485154
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=173
# cumulative regret=0.2962858202666456    Arm* regret=0.3119917782096464
# -------------------------
# END!
# Best arm is the 8th arm.
# K=10  t=1
# cumulative regret=0.20068844782078507    Arm* regret=0.24407396131049536
# -------------------------
# END!
# Best arm is the 8th arm.
# K=10  t=286
# cumulative regret=0.13397322859933447    Arm* regret=0.05350529370785513
# -------------------------
# END!
# Best arm is the 5th arm.
# K=10  t=66
# cumulative regret=0.0822441203269117    Arm* regret=0.07889567130843116
# -------------------------
# END!
# Best arm is the 0th arm.
# K=10  t=18
# cumulative regret=0.041194965830992566    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 4th arm.
# K=10  t=155
# cumulative regret=0.09547623640755784    Arm* regret=0.09735729744525809
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=1
# cumulative regret=0.18800292084742873    Arm* regret=0.17129823039612233
# -------------------------
# END!
# Best arm is the 7th arm.
# K=10  t=108
# cumulative regret=0.09905282326842217    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 4th arm.
# K=10  t=730
# cumulative regret=0.17110408023361512    Arm* regret=0.041727813324958285
# -------------------------
# END!
# Best arm is the 4th arm.
# K=10  t=381
# cumulative regret=0.05351064835748081    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 9th arm.
# K=10  t=340
# cumulative regret=0.12413152065178194    Arm* regret=0.10964336791902735
# -------------------------
# END!
# Best arm is the 2th arm.
# K=10  t=245
# cumulative regret=0.023730879663711377    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=10  t=1
# cumulative regret=0.2457950322159631    Arm* regret=0.17085502985855847
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=183
# cumulative regret=0.1505394356421718    Arm* regret=0.1344937028478865
# -------------------------
# END!
# Best arm is the 8th arm.
# K=10  t=277
# cumulative regret=0.14433633136089818    Arm* regret=0.13174909972783083
# -------------------------
# END!
# Best arm is the 6th arm.
# K=10  t=522
# cumulative regret=0.1038919539934809    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 9th arm.
# K=10  t=577
# cumulative regret=0.051065069119712404    Arm* regret=0.009913870796427277
# -------------------------
# For k=10, the regret Average is 0.14399034072888411
# ==================================================
# END!
# Best arm is the 4th arm.
# K=15  t=1
# cumulative regret=0.1022329349182593    Arm* regret=0.14748009066156623
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=1263
# cumulative regret=0.29939457150739085    Arm* regret=0.29859557832871875
# -------------------------
# END!
# Best arm is the 5th arm.
# K=15  t=109
# cumulative regret=0.20605309618095577    Arm* regret=0.23969250399430417
# -------------------------
# END!
# Best arm is the 13th arm.
# K=15  t=372
# cumulative regret=0.029453389006872936    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 4th arm.
# K=15  t=1
# cumulative regret=0.14505189219283404    Arm* regret=0.0698765492263949
# -------------------------
# END!
# Best arm is the 2th arm.
# K=15  t=1
# cumulative regret=0.17756486655115716    Arm* regret=0.14058096792127703
# -------------------------
# END!
# Best arm is the 6th arm.
# K=15  t=1049
# cumulative regret=0.11226358919397546    Arm* regret=0.12260796847474259
# -------------------------
# END!
# Best arm is the 11th arm.
# K=15  t=1
# cumulative regret=0.19518468606068554    Arm* regret=0.13675586743231538
# -------------------------
# END!
# Best arm is the 2th arm.
# K=15  t=972
# cumulative regret=0.08880393276092198    Arm* regret=0.05175782111660453
# -------------------------
# END!
# Best arm is the 11th arm.
# K=15  t=521
# cumulative regret=0.2800716633585557    Arm* regret=0.2501772154036805
# -------------------------
# END!
# Best arm is the 12th arm.
# K=15  t=1
# cumulative regret=0.10981245416122683    Arm* regret=0.16043578729882452
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=114
# cumulative regret=0.21789199953301713    Arm* regret=0.3140905807341992
# -------------------------
# END!
# Best arm is the 9th arm.
# K=15  t=209
# cumulative regret=0.18558130176936177    Arm* regret=0.188697025826981
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=1
# cumulative regret=0.2722539031125149    Arm* regret=0.2092725477058119
# -------------------------
# END!
# Best arm is the 6th arm.
# K=15  t=80
# cumulative regret=0.13799743391182945    Arm* regret=0.08174880578914015
# -------------------------
# END!
# Best arm is the 5th arm.
# K=15  t=1
# cumulative regret=0.17735061915039355    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=1
# cumulative regret=0.1400085603607865    Arm* regret=0.3475488455567034
# -------------------------
# END!
# Best arm is the 10th arm.
# K=15  t=425
# cumulative regret=0.04256707459355277    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 11th arm.
# K=15  t=630
# cumulative regret=0.19884347275912623    Arm* regret=0.20567737417359044
# -------------------------
# END!
# Best arm is the 11th arm.
# K=15  t=316
# cumulative regret=0.20109515183296653    Arm* regret=0.13810394319298908
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=1
# cumulative regret=0.211908005698782    Arm* regret=0.28956550756640387
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=1
# cumulative regret=0.173533182143312    Arm* regret=0.2543559223033402
# -------------------------
# END!
# Best arm is the 3th arm.
# K=15  t=598
# cumulative regret=0.047032243730506754    Arm* regret=0.03800615465529558
# -------------------------
# END!
# Best arm is the 6th arm.
# K=15  t=426
# cumulative regret=0.0922617387161833    Arm* regret=0.06972498168848905
# -------------------------
# END!
# Best arm is the 4th arm.
# K=15  t=1
# cumulative regret=0.24947549541979686    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 10th arm.
# K=15  t=1
# cumulative regret=0.21305432923416948    Arm* regret=0.12545351787461248
# -------------------------
# END!
# Best arm is the 6th arm.
# K=15  t=535
# cumulative regret=0.3358893000042268    Arm* regret=0.29871968848910685
# -------------------------
# END!
# Best arm is the 11th arm.
# K=15  t=152
# cumulative regret=0.1548932459715692    Arm* regret=0.16140461835445935
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=1
# cumulative regret=0.25654497741163224    Arm* regret=0.43288125356392526
# -------------------------
# END!
# Best arm is the 3th arm.
# K=15  t=1
# cumulative regret=0.23712319754550032    Arm* regret=0.17455883176037107
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=1
# cumulative regret=0.31882320762395305    Arm* regret=0.5579760657501075
# -------------------------
# END!
# Best arm is the 1th arm.
# K=15  t=611
# cumulative regret=0.25748534795032424    Arm* regret=0.2695886499474971
# -------------------------
# END!
# Best arm is the 12th arm.
# K=15  t=1
# cumulative regret=0.1969112481257283    Arm* regret=0.07429700508860984
# -------------------------
# END!
# Best arm is the 11th arm.
# K=15  t=1
# cumulative regret=0.19805936005750133    Arm* regret=0.18350639130625107
# -------------------------
# END!
# Best arm is the 4th arm.
# K=15  t=2507
# cumulative regret=0.0797143671410912    Arm* regret=0.07384482669603509
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=349
# cumulative regret=0.17278764152479248    Arm* regret=0.13011041697456543
# -------------------------
# END!
# Best arm is the 0th arm.
# K=15  t=296
# cumulative regret=0.07138582974416333    Arm* regret=0.014408745580246768
# -------------------------
# END!
# Best arm is the 7th arm.
# K=15  t=289
# cumulative regret=0.059979787668770324    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 4th arm.
# K=15  t=641
# cumulative regret=0.05888567559832485    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 7th arm.
# K=15  t=146
# cumulative regret=0.35642243833477555    Arm* regret=0.2482939144021873
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=177
# cumulative regret=0.1287637191602904    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=1
# cumulative regret=0.1430926883179063    Arm* regret=0.13933090281672814
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=1
# cumulative regret=0.33011911280205675    Arm* regret=0.31352378660995556
# -------------------------
# END!
# Best arm is the 1th arm.
# K=15  t=1
# cumulative regret=0.2719213334910149    Arm* regret=0.13388686318779933
# -------------------------
# END!
# Best arm is the 7th arm.
# K=15  t=735
# cumulative regret=0.18781067344976846    Arm* regret=0.15288319083350244
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=1
# cumulative regret=0.22652307517257184    Arm* regret=0.26095481685520494
# -------------------------
# END!
# Best arm is the 13th arm.
# K=15  t=1052
# cumulative regret=0.0951133061931114    Arm* regret=0.07223381355982289
# -------------------------
# END!
# Best arm is the 4th arm.
# K=15  t=1
# cumulative regret=0.26066402794319626    Arm* regret=0.48577063907407875
# -------------------------
# END!
# Best arm is the 7th arm.
# K=15  t=184
# cumulative regret=0.1789826205243509    Arm* regret=0.1925786454866491
# -------------------------
# END!
# Best arm is the 0th arm.
# K=15  t=190
# cumulative regret=0.0644361175316411    Arm* regret=0.02138912118584499
# -------------------------
# END!
# Best arm is the 4th arm.
# K=15  t=161
# cumulative regret=0.19414077277460273    Arm* regret=0.15778444166461425
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=1518
# cumulative regret=0.142452148345313    Arm* regret=0.13062464359201156
# -------------------------
# END!
# Best arm is the 13th arm.
# K=15  t=1
# cumulative regret=0.15454448066025223    Arm* regret=0.23019422556043134
# -------------------------
# END!
# Best arm is the 1th arm.
# K=15  t=357
# cumulative regret=0.12249792842037115    Arm* regret=0.10967906127041399
# -------------------------
# END!
# Best arm is the 13th arm.
# K=15  t=634
# cumulative regret=0.13531767433662117    Arm* regret=0.12936650840984015
# -------------------------
# END!
# Best arm is the 9th arm.
# K=15  t=1
# cumulative regret=0.24571128894341182    Arm* regret=0.3340275606557979
# -------------------------
# END!
# Best arm is the 8th arm.
# K=15  t=385
# cumulative regret=0.30011853134544525    Arm* regret=0.31283815997718184
# -------------------------
# END!
# Best arm is the 14th arm.
# K=15  t=1
# cumulative regret=0.20648284492431818    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=15  t=1
# cumulative regret=0.2616221802309464    Arm* regret=0.2017732522636277
# -------------------------
# END!
# Best arm is the 5th arm.
# K=15  t=1
# cumulative regret=0.24346394229964777    Arm* regret=0.14684206789408083
# -------------------------
# END!
# Best arm is the 7th arm.
# K=15  t=1
# cumulative regret=0.23100691264657292    Arm* regret=0.0643405935016455
# -------------------------
# END!
# Best arm is the 10th arm.
# K=15  t=121
# cumulative regret=0.1014957886333677    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 12th arm.
# K=15  t=258
# cumulative regret=0.22941550348177575    Arm* regret=0.21438013079551782
# -------------------------
# END!
# Best arm is the 9th arm.
# K=15  t=699
# cumulative regret=0.030366830031074002    Arm* regret=0.008393245741263433
# -------------------------
# For k=15, the regret Average is 0.18043297990970497
# ==================================================
# END!
# Best arm is the 11th arm.
# K=20  t=1
# cumulative regret=0.2799957973608622    Arm* regret=0.48644915489275364
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=241
# cumulative regret=0.14758786792658915    Arm* regret=0.21499625021378757
# -------------------------
# END!
# Best arm is the 18th arm.
# K=20  t=1
# cumulative regret=0.27532196334177705    Arm* regret=0.046197099030856975
# -------------------------
# END!
# Best arm is the 7th arm.
# K=20  t=1
# cumulative regret=0.2867637256586935    Arm* regret=0.5346213577782679
# -------------------------
# END!
# Best arm is the 1th arm.
# K=20  t=1
# cumulative regret=0.2292919263323936    Arm* regret=0.28762385688233744
# -------------------------
# END!
# Best arm is the 6th arm.
# K=20  t=159
# cumulative regret=0.04265846117527148    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=128
# cumulative regret=0.07352486466778983    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 11th arm.
# K=20  t=488
# cumulative regret=0.02782805203077109    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=20  t=1
# cumulative regret=0.16844691829448516    Arm* regret=0.11386155013244084
# -------------------------
# END!
# Best arm is the 11th arm.
# K=20  t=368
# cumulative regret=0.1891322898139946    Arm* regret=0.173258544359623
# -------------------------
# END!
# Best arm is the 8th arm.
# K=20  t=1
# cumulative regret=0.19905662451119452    Arm* regret=0.2977879297773328
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=1
# cumulative regret=0.2307466949865035    Arm* regret=0.25880788320490744
# -------------------------
# END!
# Best arm is the 3th arm.
# K=20  t=86
# cumulative regret=0.13052431674474427    Arm* regret=0.04139503088169415
# -------------------------
# END!
# Best arm is the 16th arm.
# K=20  t=155
# cumulative regret=0.23813347077493108    Arm* regret=0.11150283386491876
# -------------------------
# END!
# Best arm is the 7th arm.
# K=20  t=117
# cumulative regret=0.11783800069296899    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 13th arm.
# K=20  t=407
# cumulative regret=0.2066153318165949    Arm* regret=0.1482049683651832
# -------------------------
# END!
# Best arm is the 10th arm.
# K=20  t=1
# cumulative regret=0.3401939216295812    Arm* regret=0.4328499358595652
# -------------------------
# END!
# Best arm is the 4th arm.
# K=20  t=86
# cumulative regret=0.07001246438704359    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 14th arm.
# K=20  t=947
# cumulative regret=0.17682522047293298    Arm* regret=0.1702741608265323
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=1
# cumulative regret=0.49881678363413057    Arm* regret=0.5479710800618044
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=890
# cumulative regret=0.22972674455726347    Arm* regret=0.23697072997581714
# -------------------------
# END!
# Best arm is the 11th arm.
# K=20  t=1
# cumulative regret=0.24872649998607585    Arm* regret=0.1645523924053555
# -------------------------
# END!
# Best arm is the 7th arm.
# K=20  t=339
# cumulative regret=0.08302656422720034    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=1
# cumulative regret=0.17942388060463563    Arm* regret=0.2497970802660777
# -------------------------
# END!
# Best arm is the 14th arm.
# K=20  t=1
# cumulative regret=0.16755967714915015    Arm* regret=0.037067038586851286
# -------------------------
# END!
# Best arm is the 4th arm.
# K=20  t=1
# cumulative regret=0.21236456176875976    Arm* regret=0.28551136564399343
# -------------------------
# END!
# Best arm is the 18th arm.
# K=20  t=1
# cumulative regret=0.18625748528632027    Arm* regret=0.2589930165172083
# -------------------------
# END!
# Best arm is the 12th arm.
# K=20  t=373
# cumulative regret=0.05630028546492901    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 8th arm.
# K=20  t=1
# cumulative regret=0.2315260869534362    Arm* regret=0.4712529822265007
# -------------------------
# END!
# Best arm is the 12th arm.
# K=20  t=184
# cumulative regret=0.30703931261139195    Arm* regret=0.3076641481431653
# -------------------------
# END!
# Best arm is the 0th arm.
# K=20  t=957
# cumulative regret=0.06635910206398113    Arm* regret=0.009965798305805407
# -------------------------
# END!
# Best arm is the 12th arm.
# K=20  t=275
# cumulative regret=0.08418312137396045    Arm* regret=0.05400374096924887
# -------------------------
# END!
# Best arm is the 0th arm.
# K=20  t=55
# cumulative regret=0.19806611195236734    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 1th arm.
# K=20  t=669
# cumulative regret=0.18350958371642398    Arm* regret=0.1586403292034576
# -------------------------
# END!
# Best arm is the 18th arm.
# K=20  t=1
# cumulative regret=0.2165058901858342    Arm* regret=0.1660775574499727
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=1
# cumulative regret=0.21770028321167909    Arm* regret=0.16527498409069422
# -------------------------
# END!
# Best arm is the 9th arm.
# K=20  t=248
# cumulative regret=0.07341251948118892    Arm* regret=0.0028010013496702485
# -------------------------
# END!
# Best arm is the 18th arm.
# K=20  t=1
# cumulative regret=0.27905255311101373    Arm* regret=0.3596549288570238
# -------------------------
# END!
# Best arm is the 3th arm.
# K=20  t=284
# cumulative regret=0.12203403513527324    Arm* regret=0.0626065813356256
# -------------------------
# END!
# Best arm is the 5th arm.
# K=20  t=1
# cumulative regret=0.3036004767234447    Arm* regret=0.12534932689516817
# -------------------------
# END!
# Best arm is the 16th arm.
# K=20  t=1
# cumulative regret=0.21349360203345424    Arm* regret=0.25108886862709984
# -------------------------
# END!
# Best arm is the 15th arm.
# K=20  t=1
# cumulative regret=0.22808681381313092    Arm* regret=0.08349916548399114
# -------------------------
# END!
# Best arm is the 5th arm.
# K=20  t=442
# cumulative regret=0.14632443229272848    Arm* regret=0.1300610413759818
# -------------------------
# END!
# Best arm is the 13th arm.
# K=20  t=326
# cumulative regret=0.07989960554726679    Arm* regret=0.04607270572024985
# -------------------------
# END!
# Best arm is the 6th arm.
# K=20  t=1
# cumulative regret=0.2669399831899133    Arm* regret=0.4210366450801608
# -------------------------
# END!
# Best arm is the 16th arm.
# K=20  t=140
# cumulative regret=0.18941520870381778    Arm* regret=0.1909990332197769
# -------------------------
# END!
# Best arm is the 18th arm.
# K=20  t=1
# cumulative regret=0.20406076171210738    Arm* regret=0.10307488327368
# -------------------------
# END!
# Best arm is the 6th arm.
# K=20  t=1
# cumulative regret=0.18642853386299926    Arm* regret=0.0580337024011794
# -------------------------
# END!
# Best arm is the 13th arm.
# K=20  t=1
# cumulative regret=0.17367911901769228    Arm* regret=0.04059097336223483
# -------------------------
# END!
# Best arm is the 2th arm.
# K=20  t=375
# cumulative regret=0.14647125792008864    Arm* regret=0.11368318149866169
# -------------------------
# END!
# Best arm is the 9th arm.
# K=20  t=46
# cumulative regret=0.13907058882424636    Arm* regret=0.1074922676341783
# -------------------------
# END!
# Best arm is the 14th arm.
# K=20  t=1
# cumulative regret=0.27123035276621    Arm* regret=0.20990613147095094
# -------------------------
# END!
# Best arm is the 11th arm.
# K=20  t=1
# cumulative regret=0.24111567326978    Arm* regret=0.24338049084732055
# -------------------------
# END!
# Best arm is the 0th arm.
# K=20  t=175
# cumulative regret=0.03772325064311266    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 3th arm.
# K=20  t=821
# cumulative regret=0.06781788973820423    Arm* regret=0.006357212725518535
# -------------------------
# END!
# Best arm is the 3th arm.
# K=20  t=260
# cumulative regret=0.2231294018825275    Arm* regret=0.12648166244540884
# -------------------------
# END!
# Best arm is the 18th arm.
# K=20  t=877
# cumulative regret=0.05620521998582256    Arm* regret=0.05298219233671154
# -------------------------
# END!
# Best arm is the 14th arm.
# K=20  t=268
# cumulative regret=0.03061724123308586    Arm* regret=0.01388749226353092
# -------------------------
# END!
# Best arm is the 4th arm.
# K=20  t=151
# cumulative regret=0.1592137237103962    Arm* regret=0.1576671219573588
# -------------------------
# END!
# Best arm is the 2th arm.
# K=20  t=226
# cumulative regret=0.18641915121286243    Arm* regret=0.17230139845586306
# -------------------------
# END!
# Best arm is the 10th arm.
# K=20  t=1
# cumulative regret=0.21865534552184895    Arm* regret=0.3100049830709455
# -------------------------
# END!
# Best arm is the 18th arm.
# K=20  t=1
# cumulative regret=0.22436046475737348    Arm* regret=0.09824363462227326
# -------------------------
# END!
# Best arm is the 10th arm.
# K=20  t=226
# cumulative regret=0.18999381441161867    Arm* regret=0.17013389355795086
# -------------------------
# END!
# Best arm is the 10th arm.
# K=20  t=1
# cumulative regret=0.28522248901036756    Arm* regret=0.4773198303834637
# -------------------------
# For k=20, the regret Average is 0.18345724057622248
# ==================================================
# END!
# Best arm is the 23th arm.
# K=25  t=403
# cumulative regret=0.10125018953086855    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 12th arm.
# K=25  t=65
# cumulative regret=0.13328279498233794    Arm* regret=0.1321868722484212
# -------------------------
# END!
# Best arm is the 19th arm.
# K=25  t=760
# cumulative regret=0.18650879780885446    Arm* regret=0.20374282117762965
# -------------------------
# END!
# Best arm is the 4th arm.
# K=25  t=1
# cumulative regret=0.2711329538956151    Arm* regret=0.3528403717407498
# -------------------------
# END!
# Best arm is the 19th arm.
# K=25  t=1403
# cumulative regret=0.13816209458653095    Arm* regret=0.12431491835400196
# -------------------------
# END!
# Best arm is the 10th arm.
# K=25  t=1
# cumulative regret=0.2962480409350507    Arm* regret=0.36794646179250057
# -------------------------
# END!
# Best arm is the 8th arm.
# K=25  t=1
# cumulative regret=0.19748474924656298    Arm* regret=0.26610996915416785
# -------------------------
# END!
# Best arm is the 6th arm.
# K=25  t=1
# cumulative regret=0.2787214605511421    Arm* regret=0.3545925446912708
# -------------------------
# END!
# Best arm is the 13th arm.
# K=25  t=392
# cumulative regret=0.22036037015006746    Arm* regret=0.20721168305646975
# -------------------------
# END!
# Best arm is the 23th arm.
# K=25  t=1
# cumulative regret=0.30445410818269475    Arm* regret=0.2602872854423911
# -------------------------
# END!
# Best arm is the 16th arm.
# K=25  t=1
# cumulative regret=0.26926214938198484    Arm* regret=0.35888748707429574
# -------------------------
# END!
# Best arm is the 13th arm.
# K=25  t=1
# cumulative regret=0.24016030209784045    Arm* regret=0.3539660582476105
# -------------------------
# END!
# Best arm is the 21th arm.
# K=25  t=514
# cumulative regret=0.1466989476782347    Arm* regret=0.06354086126602002
# -------------------------
# END!
# Best arm is the 23th arm.
# K=25  t=474
# cumulative regret=0.06913390625213463    Arm* regret=0.0091122665971968
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=1
# cumulative regret=0.22871828130488778    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 10th arm.
# K=25  t=1
# cumulative regret=0.1803009963392084    Arm* regret=0.08323772049685399
# -------------------------
# END!
# Best arm is the 16th arm.
# K=25  t=282
# cumulative regret=0.2721301447760187    Arm* regret=0.24039903786389155
# -------------------------
# END!
# Best arm is the 4th arm.
# K=25  t=537
# cumulative regret=0.24171803257579744    Arm* regret=0.21963143830801693
# -------------------------
# END!
# Best arm is the 9th arm.
# K=25  t=1
# cumulative regret=0.17101213397239248    Arm* regret=0.34855990256591496
# -------------------------
# END!
# Best arm is the 3th arm.
# K=25  t=615
# cumulative regret=0.2791895099633558    Arm* regret=0.24872796454636847
# -------------------------
# END!
# Best arm is the 12th arm.
# K=25  t=1
# cumulative regret=0.3690286795278562    Arm* regret=0.3173142946747333
# -------------------------
# END!
# Best arm is the 18th arm.
# K=25  t=877
# cumulative regret=0.25700355541869413    Arm* regret=0.22637311933558146
# -------------------------
# END!
# Best arm is the 10th arm.
# K=25  t=350
# cumulative regret=0.23087108599879594    Arm* regret=0.2051294506560391
# -------------------------
# END!
# Best arm is the 19th arm.
# K=25  t=350
# cumulative regret=0.20351648346313717    Arm* regret=0.2396253781019949
# -------------------------
# END!
# Best arm is the 16th arm.
# K=25  t=293
# cumulative regret=0.17576556172447763    Arm* regret=0.15386729145595837
# -------------------------
# END!
# Best arm is the 24th arm.
# K=25  t=617
# cumulative regret=0.1817089509790828    Arm* regret=0.17097152394756282
# -------------------------
# END!
# Best arm is the 8th arm.
# K=25  t=752
# cumulative regret=0.40490892532680295    Arm* regret=0.3094071708309173
# -------------------------
# END!
# Best arm is the 24th arm.
# K=25  t=1
# cumulative regret=0.19601123472049098    Arm* regret=0.3086062542085983
# -------------------------
# END!
# Best arm is the 24th arm.
# K=25  t=116
# cumulative regret=0.220132528119226    Arm* regret=0.20631054069709603
# -------------------------
# END!
# Best arm is the 21th arm.
# K=25  t=1
# cumulative regret=0.22656282450192702    Arm* regret=0.1524772379672374
# -------------------------
# END!
# Best arm is the 6th arm.
# K=25  t=1
# cumulative regret=0.2801225815840084    Arm* regret=0.41856487226016337
# -------------------------
# END!
# Best arm is the 17th arm.
# K=25  t=682
# cumulative regret=0.3207388312221323    Arm* regret=0.2862835338987436
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=506
# cumulative regret=0.1165230731495743    Arm* regret=0.05462825211972536
# -------------------------
# END!
# Best arm is the 14th arm.
# K=25  t=437
# cumulative regret=0.05141476111400099    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 19th arm.
# K=25  t=1542
# cumulative regret=0.061487247385989666    Arm* regret=0.011127830026713137
# -------------------------
# END!
# Best arm is the 22th arm.
# K=25  t=764
# cumulative regret=0.16160137407409794    Arm* regret=0.15652734959613473
# -------------------------
# END!
# Best arm is the 24th arm.
# K=25  t=1
# cumulative regret=0.17102399363131165    Arm* regret=0.10287119999495657
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=580
# cumulative regret=0.13689607386539487    Arm* regret=0.11533566492538737
# -------------------------
# END!
# Best arm is the 7th arm.
# K=25  t=1
# cumulative regret=0.23564633839764623    Arm* regret=0.4334330705771758
# -------------------------
# END!
# Best arm is the 24th arm.
# K=25  t=1
# cumulative regret=0.27762307012753357    Arm* regret=0.4467854384060901
# -------------------------
# END!
# Best arm is the 2th arm.
# K=25  t=1
# cumulative regret=0.26923584259400024    Arm* regret=0.12210309417467255
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=1052
# cumulative regret=0.009506132456950875    Arm* regret=0.011509857329586898
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=1
# cumulative regret=0.23537584427171154    Arm* regret=0.2659147532298893
# -------------------------
# END!
# Best arm is the 7th arm.
# K=25  t=464
# cumulative regret=0.09403024848362057    Arm* regret=0.08418754580361992
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=281
# cumulative regret=0.12305403472893019    Arm* regret=0.13074208578365507
# -------------------------
# END!
# Best arm is the 20th arm.
# K=25  t=1
# cumulative regret=0.23419549075312593    Arm* regret=0.2719353728275293
# -------------------------
# END!
# Best arm is the 10th arm.
# K=25  t=1
# cumulative regret=0.21173269891680097    Arm* regret=0.3225741625578995
# -------------------------
# END!
# Best arm is the 17th arm.
# K=25  t=1
# cumulative regret=0.19739707713245994    Arm* regret=0.006257700486441753
# -------------------------
# END!
# Best arm is the 1th arm.
# K=25  t=1
# cumulative regret=0.32688352385607095    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=191
# cumulative regret=0.027098860669518825    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 22th arm.
# K=25  t=414
# cumulative regret=0.031089152783661533    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=25  t=863
# cumulative regret=0.032900833530734676    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 23th arm.
# K=25  t=1
# cumulative regret=0.150169445843563    Arm* regret=0.17557095229902064
# -------------------------
# END!
# Best arm is the 5th arm.
# K=25  t=564
# cumulative regret=0.2756607947837209    Arm* regret=0.26290666133255386
# -------------------------
# END!
# Best arm is the 5th arm.
# K=25  t=401
# cumulative regret=0.08347417188769522    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 9th arm.
# K=25  t=592
# cumulative regret=0.2605372684211553    Arm* regret=0.31387472692533536
# -------------------------
# END!
# Best arm is the 10th arm.
# K=25  t=1
# cumulative regret=0.3209125004371032    Arm* regret=0.48788024060261737
# -------------------------
# END!
# Best arm is the 22th arm.
# K=25  t=703
# cumulative regret=0.06456500338554037    Arm* regret=0.04846662916463687
# -------------------------
# END!
# Best arm is the 23th arm.
# K=25  t=1
# cumulative regret=0.21907116527965553    Arm* regret=0.18747109638251563
# -------------------------
# END!
# Best arm is the 22th arm.
# K=25  t=473
# cumulative regret=0.03639390738979988    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 6th arm.
# K=25  t=1
# cumulative regret=0.23412416340044453    Arm* regret=0.33511893578956076
# -------------------------
# END!
# Best arm is the 15th arm.
# K=25  t=1
# cumulative regret=0.2956645952945967    Arm* regret=0.22549658090564612
# -------------------------
# END!
# Best arm is the 7th arm.
# K=25  t=264
# cumulative regret=0.0701735546227674    Arm* regret=0.05936175624603951
# -------------------------
# END!
# Best arm is the 24th arm.
# K=25  t=739
# cumulative regret=0.14674303175131545    Arm* regret=0.1195301489607255
# -------------------------
# For k=25, the regret Average is 0.19460166376904225
# ==================================================
# END!
# Best arm is the 28th arm.
# K=30  t=1
# cumulative regret=0.22751562697357663    Arm* regret=0.301463875625669
# -------------------------
# END!
# Best arm is the 23th arm.
# K=30  t=381
# cumulative regret=0.054785967313077895    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 21th arm.
# K=30  t=77
# cumulative regret=0.08997244365960005    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 20th arm.
# K=30  t=533
# cumulative regret=0.17278564624594053    Arm* regret=0.16174094239235712
# -------------------------
# END!
# Best arm is the 22th arm.
# K=30  t=372
# cumulative regret=0.03171505466394797    Arm* regret=0.017988009092036156
# -------------------------
# END!
# Best arm is the 22th arm.
# K=30  t=663
# cumulative regret=0.07812829646683912    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 15th arm.
# K=30  t=1
# cumulative regret=0.2648256290169717    Arm* regret=0.36493290175712134
# -------------------------
# END!
# Best arm is the 9th arm.
# K=30  t=184
# cumulative regret=0.05401481184886594    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 28th arm.
# K=30  t=186
# cumulative regret=0.21016853131260255    Arm* regret=0.13944646592820548
# -------------------------
# END!
# Best arm is the 21th arm.
# K=30  t=613
# cumulative regret=0.17648203367457418    Arm* regret=0.1631491890497097
# -------------------------
# END!
# Best arm is the 8th arm.
# K=30  t=248
# cumulative regret=0.3458885295803918    Arm* regret=0.3145188880465311
# -------------------------
# END!
# Best arm is the 28th arm.
# K=30  t=1
# cumulative regret=0.251913384936492    Arm* regret=0.3218730108366353
# -------------------------
# END!
# Best arm is the 29th arm.
# K=30  t=1
# cumulative regret=0.20478015919847734    Arm* regret=0.272984150638691
# -------------------------
# END!
# Best arm is the 1th arm.
# K=30  t=584
# cumulative regret=0.2041102313858625    Arm* regret=0.17624231006940883
# -------------------------
# END!
# Best arm is the 22th arm.
# K=30  t=1
# cumulative regret=0.3006462215327666    Arm* regret=0.29018454469756316
# -------------------------
# END!
# Best arm is the 29th arm.
# K=30  t=1
# cumulative regret=0.2634394104102569    Arm* regret=0.29415288397549877
# -------------------------
# END!
# Best arm is the 17th arm.
# K=30  t=1034
# cumulative regret=0.1442724500967167    Arm* regret=0.09949981180495729
# -------------------------
# END!
# Best arm is the 19th arm.
# K=30  t=1409
# cumulative regret=0.26136463612248156    Arm* regret=0.18251345769311914
# -------------------------
# END!
# Best arm is the 7th arm.
# K=30  t=1
# cumulative regret=0.17751893833365298    Arm* regret=0.30437038224033885
# -------------------------
# END!
# Best arm is the 20th arm.
# K=30  t=1
# cumulative regret=0.2525902081387791    Arm* regret=0.22449418570670063
# -------------------------
# END!
# Best arm is the 15th arm.
# K=30  t=1061
# cumulative regret=0.13791844389121843    Arm* regret=0.15860618295694173
# -------------------------
# END!
# Best arm is the 2th arm.
# K=30  t=136
# cumulative regret=0.09537027727377853    Arm* regret=0.004313682410992892
# -------------------------
# END!
# Best arm is the 14th arm.
# K=30  t=171
# cumulative regret=0.032561813697047616    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 0th arm.
# K=30  t=515
# cumulative regret=0.2521530144729619    Arm* regret=0.24626505990140313
# -------------------------
# END!
# Best arm is the 6th arm.
# K=30  t=1987
# cumulative regret=0.24545319406996596    Arm* regret=0.2975561297639898
# -------------------------
# END!
# Best arm is the 1th arm.
# K=30  t=1
# cumulative regret=0.20336438178755395    Arm* regret=0.061541172313953896
# -------------------------
# END!
# Best arm is the 8th arm.
# K=30  t=833
# ...
# -------------------------
# END!
# Best arm is the 26th arm.
# K=45  t=769
# cumulative regret=0.07177450714029843    Arm* regret=0.06148902892885863
# -------------------------
# END!
# Best arm is the 35th arm.
# K=45  t=1
# cumulative regret=0.2580370431242377    Arm* regret=0.030066362371814787
# -------------------------
# END!
# Best arm is the 43th arm.
# K=45  t=1
# cumulative regret=0.3215347505733251    Arm* regret=0.3544693580049692
# -------------------------
# END!
# Best arm is the 19th arm.
# K=45  t=1
# cumulative regret=0.3223004919689487    Arm* regret=0.09355745802016593
# -------------------------
# END!
# Best arm is the 39th arm.
# K=45  t=1
# cumulative regret=0.36279962375876973    Arm* regret=0.36999408008290596
# -------------------------
# END!
# Best arm is the 4th arm.
# K=45  t=701
# cumulative regret=0.24440150138667188    Arm* regret=0.20351669358260388
# -------------------------
# END!
# Best arm is the 5th arm.
# K=45  t=1
# cumulative regret=0.167884270339855    Arm* regret=0.10125649784986315
# -------------------------
# END!
# Best arm is the 12th arm.
# K=45  t=432
# cumulative regret=0.2249274312928116    Arm* regret=0.08365960063225267
# -------------------------
# END!
# Best arm is the 5th arm.
# K=45  t=469
# cumulative regret=0.19021068180030337    Arm* regret=0.0525676135840229
# -------------------------
# END!
# Best arm is the 3th arm.
# K=45  t=1
# cumulative regret=0.22934453594101803    Arm* regret=0.2400380153524326
# -------------------------
# END!
# Best arm is the 44th arm.
# K=45  t=295
# cumulative regret=0.28970490054018644    Arm* regret=0.14161367308139614
# -------------------------
# END!
# Best arm is the 39th arm.
# K=45  t=909
# cumulative regret=0.26286476197881864    Arm* regret=0.23623136022737462
# -------------------------
# END!
# Best arm is the 6th arm.
# K=45  t=836
# cumulative regret=0.19028921471978014    Arm* regret=0.17729111664300315
# -------------------------
# END!
# Best arm is the 39th arm.
# K=45  t=1
# cumulative regret=0.16291972725235737    Arm* regret=0.10864542990302098
# -------------------------
# END!
# Best arm is the 17th arm.
# K=45  t=593
# cumulative regret=0.07459984734651974    Arm* regret=0.02926638326799258
# -------------------------
# END!
# Best arm is the 9th arm.
# K=45  t=690
# cumulative regret=0.1404668916670467    Arm* regret=0.11155364474357199
# -------------------------
# END!
# Best arm is the 33th arm.
# K=45  t=416
# cumulative regret=0.21092513923023976    Arm* regret=0.1692272260953902
# -------------------------
# END!
# Best arm is the 28th arm.
# K=45  t=535
# cumulative regret=0.15715370316389352    Arm* regret=0.14008803015621105
# -------------------------
# END!
# Best arm is the 25th arm.
# K=45  t=1
# cumulative regret=0.1781128427028453    Arm* regret=0.19740779824179652
# -------------------------
# END!
# Best arm is the 21th arm.
# K=45  t=1
# cumulative regret=0.3089695119895472    Arm* regret=0.18638951777436705
# -------------------------
# END!
# Best arm is the 34th arm.
# K=45  t=236
# cumulative regret=0.16255935085675163    Arm* regret=0.04219974424424744
# -------------------------
# END!
# Best arm is the 44th arm.
# K=45  t=1
# cumulative regret=0.2105244219589126    Arm* regret=0.09566358650715018
# -------------------------
# END!
# Best arm is the 9th arm.
# K=45  t=501
# cumulative regret=0.19657997332593125    Arm* regret=0.1942281974364916
# -------------------------
# END!
# Best arm is the 8th arm.
# K=45  t=482
# cumulative regret=0.14467555938188922    Arm* regret=0.1221579010703508
# -------------------------
# END!
# Best arm is the 4th arm.
# K=45  t=170
# cumulative regret=0.33566334790026453    Arm* regret=0.34109613296204555
# -------------------------
# END!
# Best arm is the 44th arm.
# K=45  t=644
# cumulative regret=0.2853350958785155    Arm* regret=0.22215334987959834
# -------------------------
# END!
# Best arm is the 43th arm.
# K=45  t=932
# cumulative regret=0.09324385584947999    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 17th arm.
# K=45  t=1
# cumulative regret=0.28461547462955916    Arm* regret=0.319508266349319
# -------------------------
# END!
# Best arm is the 33th arm.
# K=45  t=757
# cumulative regret=0.2014473674188314    Arm* regret=0.11235813487673293
# -------------------------
# END!
# Best arm is the 35th arm.
# K=45  t=328
# cumulative regret=0.02860717972144023    Arm* regret=0.01083160657518105
# -------------------------
# END!
# Best arm is the 10th arm.
# K=45  t=239
# cumulative regret=0.29699694363132895    Arm* regret=0.2869756322004292
# -------------------------
# END!
# Best arm is the 14th arm.
# K=45  t=1
# cumulative regret=0.32177021526978317    Arm* regret=0.5026784116868384
# -------------------------
# END!
# Best arm is the 22th arm.
# K=45  t=1
# cumulative regret=0.2614552479047231    Arm* regret=0.2628442609633045
# -------------------------
# END!
# Best arm is the 5th arm.
# K=45  t=1
# cumulative regret=0.30044310448861417    Arm* regret=0.21798026897405215
# -------------------------
# END!
# Best arm is the 1th arm.
# K=45  t=1
# cumulative regret=0.32875377887735363    Arm* regret=0.3315756787823034
# -------------------------
# END!
# Best arm is the 23th arm.
# K=45  t=1
# cumulative regret=0.27834194558033176    Arm* regret=0.3768260048778439
# -------------------------
# END!
# Best arm is the 16th arm.
# K=45  t=668
# cumulative regret=0.04930130270254344    Arm* regret=0.036504089208225815
# -------------------------
# END!
# Best arm is the 29th arm.
# K=45  t=1
# cumulative regret=0.2928601560758484    Arm* regret=0.3820921352261316
# -------------------------
# END!
# Best arm is the 8th arm.
# K=45  t=730
# cumulative regret=0.042375719176063614    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 7th arm.
# K=45  t=723
# cumulative regret=0.12857968481250162    Arm* regret=0.052313973485012405
# -------------------------
# END!
# Best arm is the 26th arm.
# K=45  t=58
# cumulative regret=0.03758377142449141    Arm* regret=0.011535719762321067
# -------------------------
# END!
# Best arm is the 13th arm.
# K=45  t=515
# cumulative regret=0.29637217172978136    Arm* regret=0.28715720069656714
# -------------------------
# END!
# Best arm is the 3th arm.
# K=45  t=1
# cumulative regret=0.2666302376497472    Arm* regret=0.3347987667210087
# -------------------------
# END!
# Best arm is the 26th arm.
# K=45  t=1366
# cumulative regret=0.21033135645200646    Arm* regret=0.20493608977984099
# -------------------------
# END!
# Best arm is the 20th arm.
# K=45  t=1
# cumulative regret=0.35909270404171695    Arm* regret=0.3270288697153823
# -------------------------
# END!
# Best arm is the 26th arm.
# K=45  t=740
# cumulative regret=0.2980579941119271    Arm* regret=0.2673831354449184
# -------------------------
# END!
# Best arm is the 1th arm.
# K=45  t=1
# cumulative regret=0.21393614688973564    Arm* regret=0.19317256625881937
# -------------------------
# END!
# Best arm is the 43th arm.
# K=45  t=1
# cumulative regret=0.28401999607039485    Arm* regret=0.07272642302858232
# -------------------------
# END!
# Best arm is the 27th arm.
# K=45  t=1
# cumulative regret=0.2584690074098825    Arm* regret=0.21503105551082688
# -------------------------
# For k=45, the regret Average is 0.22404951638583565
# ==================================================
# END!
# Best arm is the 20th arm.
# K=50  t=1
# cumulative regret=0.31037757349695083    Arm* regret=0.2702695915911716
# -------------------------
# END!
# Best arm is the 29th arm.
# K=50  t=1
# cumulative regret=0.3049313987307292    Arm* regret=0.4426785506997938
# -------------------------
# END!
# Best arm is the 27th arm.
# K=50  t=1
# cumulative regret=0.1911826657851408    Arm* regret=0.42779592347709583
# -------------------------
# END!
# Best arm is the 16th arm.
# K=50  t=1
# cumulative regret=0.26123868541807366    Arm* regret=0.34918653147533646
# -------------------------
# END!
# Best arm is the 18th arm.
# K=50  t=1
# cumulative regret=0.2614970775411168    Arm* regret=0.3016472951651483
# -------------------------
# END!
# Best arm is the 49th arm.
# K=50  t=1580
# cumulative regret=0.04836654295604676    Arm* regret=0.022483237753931906
# -------------------------
# END!
# Best arm is the 0th arm.
# K=50  t=1
# cumulative regret=0.20293584402111178    Arm* regret=0.19446171292033898
# -------------------------
# END!
# Best arm is the 44th arm.
# K=50  t=1
# cumulative regret=0.24706429074567973    Arm* regret=0.2752798780746639
# -------------------------
# END!
# Best arm is the 13th arm.
# K=50  t=2357
# cumulative regret=0.15459455140996    Arm* regret=0.02670557305788776
# -------------------------
# END!
# Best arm is the 47th arm.
# K=50  t=1
# cumulative regret=0.23741229740549163    Arm* regret=0.241152126222364
# -------------------------
# END!
# Best arm is the 5th arm.
# K=50  t=401
# cumulative regret=0.13172670873106496    Arm* regret=0.02987349567808456
# -------------------------
# END!
# Best arm is the 4th arm.
# K=50  t=333
# cumulative regret=0.24247173475992423    Arm* regret=0.14589540446886903
# -------------------------
# END!
# Best arm is the 47th arm.
# K=50  t=1
# cumulative regret=0.27078660623803796    Arm* regret=0.34030071200807965
# -------------------------
# END!
# Best arm is the 16th arm.
# K=50  t=171
# cumulative regret=0.16097240320920336    Arm* regret=0.0967111145353082
# -------------------------
# END!
# Best arm is the 13th arm.
# K=50  t=1
# cumulative regret=0.3494451654432499    Arm* regret=0.3694102766350501
# -------------------------
# END!
# Best arm is the 39th arm.
# K=50  t=1379
# cumulative regret=0.21478019008213925    Arm* regret=0.12082344638627408
# -------------------------
# END!
# Best arm is the 39th arm.
# K=50  t=1
# cumulative regret=0.23464569015613954    Arm* regret=0.13267661574231496
# -------------------------
# END!
# Best arm is the 0th arm.
# K=50  t=1
# cumulative regret=0.388679331315656    Arm* regret=0.6460427802259661
# -------------------------
# END!
# Best arm is the 39th arm.
# K=50  t=981
# cumulative regret=0.10319077153697141    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 42th arm.
# K=50  t=405
# cumulative regret=0.27798055618912254    Arm* regret=0.20204811732212744
# -------------------------
# END!
# Best arm is the 4th arm.
# K=50  t=1
# cumulative regret=0.238293688731864    Arm* regret=0.24518549256807767
# -------------------------
# END!
# Best arm is the 19th arm.
# K=50  t=1
# cumulative regret=0.32455228242162554    Arm* regret=0.602519283720574
# -------------------------
# END!
# Best arm is the 47th arm.
# K=50  t=345
# cumulative regret=0.21299265807442763    Arm* regret=0.14694869025258012
# -------------------------
# END!
# Best arm is the 2th arm.
# K=50  t=1
# cumulative regret=0.3088549824146608    Arm* regret=0.24674053602665696
# -------------------------
# END!
# Best arm is the 10th arm.
# K=50  t=1291
# cumulative regret=0.10281399478738712    Arm* regret=0.08351101740373859
# -------------------------
# END!
# Best arm is the 26th arm.
# K=50  t=1
# cumulative regret=0.2786909616478075    Arm* regret=0.34998733864594017
# -------------------------
# END!
# Best arm is the 7th arm.
# K=50  t=592
# cumulative regret=0.23758593837894085    Arm* regret=0.2094345484097299
# -------------------------
# END!
# Best arm is the 46th arm.
# K=50  t=242
# cumulative regret=0.20715776475277636    Arm* regret=0.1858964159256836
# -------------------------
# END!
# Best arm is the 23th arm.
# K=50  t=732
# cumulative regret=0.06106550885974768    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 17th arm.
# K=50  t=1
# cumulative regret=0.2471084109654124    Arm* regret=0.3222501629155138
# -------------------------
# END!
# Best arm is the 11th arm.
# K=50  t=1
# cumulative regret=0.3123685151141266    Arm* regret=0.2830809456814724
# -------------------------
# END!
# Best arm is the 31th arm.
# K=50  t=1
# cumulative regret=0.28053512499340927    Arm* regret=0.30637398342931865
# -------------------------
# END!
# Best arm is the 11th arm.
# K=50  t=1
# cumulative regret=0.2905980198455623    Arm* regret=0.14607586209035558
# -------------------------
# END!
# Best arm is the 44th arm.
# K=50  t=658
# cumulative regret=0.14027649784583732    Arm* regret=0.08695567865675399
# -------------------------
# END!
# Best arm is the 17th arm.
# K=50  t=1
# cumulative regret=0.23398142134179917    Arm* regret=0.47915126105365274
# -------------------------
# END!
# Best arm is the 26th arm.
# K=50  t=1
# cumulative regret=0.35747898942461254    Arm* regret=0.34064347928224453
# -------------------------
# END!
# Best arm is the 18th arm.
# K=50  t=1
# cumulative regret=0.29933748970612706    Arm* regret=0.30935636745546874
# -------------------------
# END!
# Best arm is the 8th arm.
# K=50  t=622
# cumulative regret=0.22599484846802015    Arm* regret=0.18843003799764493
# -------------------------
# END!
# Best arm is the 24th arm.
# K=50  t=1229
# cumulative regret=0.10943851629056188    Arm* regret=0.04609225356371549
# -------------------------
# END!
# Best arm is the 2th arm.
# K=50  t=1
# cumulative regret=0.3812884231339345    Arm* regret=0.3537750066506823
# -------------------------
# END!
# Best arm is the 7th arm.
# K=50  t=1
# cumulative regret=0.20644649932197684    Arm* regret=0.45997609878358847
# -------------------------
# END!
# Best arm is the 12th arm.
# K=50  t=1
# cumulative regret=0.25673443996604506    Arm* regret=0.4757327938777426
# -------------------------
# END!
# Best arm is the 36th arm.
# K=50  t=481
# cumulative regret=0.250434663817373    Arm* regret=0.19026763298217342
# -------------------------
# END!
# Best arm is the 37th arm.
# K=50  t=422
# cumulative regret=0.261942148436409    Arm* regret=0.17813643704658472
# -------------------------
# END!
# Best arm is the 3th arm.
# K=50  t=1184
# cumulative regret=0.10818296427197903    Arm* regret=0.07001233470745516
# -------------------------
# END!
# Best arm is the 23th arm.
# K=50  t=1172
# cumulative regret=0.30678286545646355    Arm* regret=0.16860860767034364
# -------------------------
# END!
# Best arm is the 26th arm.
# K=50  t=567
# cumulative regret=0.05042993753816376    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 23th arm.
# K=50  t=318
# cumulative regret=0.055730538355432804    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 48th arm.
# K=50  t=1
# cumulative regret=0.19188643968695973    Arm* regret=0.2050221392934842
# -------------------------
# END!
# Best arm is the 32th arm.
# K=50  t=875
# cumulative regret=0.24306096638607083    Arm* regret=0.25483438216197457
# -------------------------
# END!
# Best arm is the 28th arm.
# K=50  t=1
# cumulative regret=0.30053081291300193    Arm* regret=0.30189761342736326
# -------------------------
# END!
# Best arm is the 24th arm.
# K=50  t=677
# cumulative regret=0.24426356015493378    Arm* regret=0.25204501760942183
# -------------------------
# END!
# Best arm is the 26th arm.
# K=50  t=777
# cumulative regret=0.24997046298992434    Arm* regret=0.07470718077250535
# -------------------------
# END!
# Best arm is the 39th arm.
# K=50  t=1
# cumulative regret=0.3752720255965948    Arm* regret=0.41344733858514116
# -------------------------
# END!
# Best arm is the 20th arm.
# K=50  t=1
# cumulative regret=0.27411884722753094    Arm* regret=0.31274915822329796
# -------------------------
# END!
# Best arm is the 18th arm.
# K=50  t=743
# cumulative regret=0.13163704957077837    Arm* regret=0.15714362458311718
# -------------------------
# END!
# Best arm is the 38th arm.
# K=50  t=2131
# cumulative regret=0.11291697978721378    Arm* regret=0.05464560010615116
# -------------------------
# END!
# Best arm is the 42th arm.
# K=50  t=1
# cumulative regret=0.31093209355328844    Arm* regret=0.1142340373503874
# -------------------------
# END!
# Best arm is the 44th arm.
# K=50  t=739
# cumulative regret=0.19167242417646388    Arm* regret=0.1599982282825737
# -------------------------
# END!
# Best arm is the 17th arm.
# K=50  t=1
# cumulative regret=0.37670694605669613    Arm* regret=0.21760560220620392
# -------------------------
# END!
# Best arm is the 33th arm.
# K=50  t=1202
# cumulative regret=0.2371881061390331    Arm* regret=0.1799727105360748
# -------------------------
# END!
# Best arm is the 3th arm.
# K=50  t=1
# cumulative regret=0.24665956475033096    Arm* regret=0.2226186031498132
# -------------------------
# END!
# Best arm is the 40th arm.
# K=50  t=428
# cumulative regret=0.054080924088512526    Arm* regret=0.0
# -------------------------
# END!
# Best arm is the 38th arm.
# K=50  t=1310
# cumulative regret=0.06955392638228969    Arm* regret=0.03128026550592844
# -------------------------
# For k=50, the regret Average is 0.22737233295302994
# ==================================================

# %%
# save the outcome to an frame
FinalData = {"Cu_Regret": np.mean(Cu_Regret, axis = 1), "stopping_time": np.mean(stop_time, axis = 1),
             "Regret": np.mean(Regret, axis = 1)}
df = pd.DataFrame(FinalData)
df.to_excel('./Result.xlsx', index = False)

# %%
# calculate standard error to plot a figure
Cu_Re_std = np.zeros(10)
Re_std = np.zeros(10)
St_std = np.zeros(10)
for k in range(0, 10):
    Cu_Re_std[k] = np.std(Cu_Regret[k])
    Re_std[k] = np.std(Regret[k])
    St_std[k] = np.std(stop_time[k])

# %%
# plot the figure of cumulative regret
K = np.sqrt(np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50]))
plt.figure(figsize = (12, 7), dpi = 60)
plt.errorbar(K, np.mean(Cu_Regret, axis = 1), Cu_Re_std, fmt = 'o-', ecolor = 'dodgerblue', color = 'dodgerblue')
plt.title('Cumulative Regret Average', fontsize = 30)
plt.xlabel('K^(1/2)', fontsize = 20)
plt.ylabel('Cumulative Regret Average', fontsize = 20)
plt.savefig('./Cumulative_Regret_Average.png')

# %%
# plot the figure of arm*'s regret
K = np.sqrt(np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50]))
plt.figure(figsize = (12, 7), dpi = 60)
plt.errorbar(K, np.mean(Regret, axis = 1), Re_std, fmt = 'o-', ecolor = 'turquoise', color = 'turquoise')
plt.title('Arm Regret Average', fontsize = 30)
plt.xlabel('K^(1/2)', fontsize = 20)
plt.ylabel('Arm Regret Average', fontsize = 20)
plt.savefig('./Arm_Regret_Average.png')

# %%
# plot the figure of stopping
K = np.sqrt(np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50]))
plt.figure(figsize = (12, 7), dpi = 60)
plt.errorbar(K, np.mean(stop_time, axis = 1), St_std, fmt = 'o-', ecolor = 'orange', color = 'orange')
plt.title('Stopping time Average', fontsize = 30)
plt.xlabel('K^(1/2)', fontsize = 20)
plt.ylabel('Stopping time Average', fontsize = 20)
plt.savefig('./Stopping_time_Average.png')
